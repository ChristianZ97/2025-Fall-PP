# %%
# Install flash-attn Package (About 20 Min)
# !pip install flash-attn==1.0.9 --no-build-isolation -q

# !pip install wandb -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 17.2 MB/s eta 0:00:00
#   Building wheel for flash-attn (setup.py) ... done

# %%
import torch
# !nvidia-smi
print("CUDA Usage :", torch.cuda.is_available())
print("GPU :", torch.cuda.get_device_name(0))
# Out:
# Wed Nov 26 16:25:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CUDA Usage : True
# GPU : Tesla T4

# %%
import wandb

import math
import json
import torch
import torch.nn.functional as F
from einops import rearrange
from flash_attn.flash_attn_interface import flash_attn_unpadded_qkvpacked_func

# ---------------------------
# FLOPs and Efficiency Calculation
# ---------------------------
def flops(batch_size, seq_len, head_dim, num_heads, causal, mode='fwd'):
    assert mode in ['fwd', 'bwd', 'fwd_bwd']
    f = 4 * batch_size * seq_len**2 * num_heads * head_dim // (2 if causal else 1)
    return f if mode == 'fwd' else (2.5 * f if mode == 'bwd' else 3.5 * f)

def efficiency(flop, time):
    return (flop / time / 10**12) if time > 0 else 0.0

# ---------------------------
# Custom Benchmark Function
# ---------------------------
def benchmark_fwd_bwd(func, qkv, cu_seqlens, dropout_p, causal, repeats=30):
    fwd_times, bwd_times = [], []
    for _ in range(repeats):
        torch.cuda.synchronize()
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)

        start.record()
        out = func(qkv, cu_seqlens, qkv.shape[0], dropout_p, causal=causal)
        end.record()
        torch.cuda.synchronize()
        fwd_times.append(start.elapsed_time(end) / 1000.0)

        grad = torch.randn_like(out)
        start.record()
        out.backward(grad, retain_graph=True)
        end.record()
        torch.cuda.synchronize()
        bwd_times.append(start.elapsed_time(end) / 1000.0)

    return fwd_times, bwd_times

# ---------------------------
# PyTorch baseline attention
# ---------------------------
def pytorch_attn_func(qkv, dropout_p=0.0, causal=True):
    batch_size, seq_len, _, num_heads, head_dim = qkv.shape
    q, k, v = qkv.unbind(dim=2)
    q = rearrange(q, 'b t h d -> (b h) t d')
    k = rearrange(k, 'b s h d -> (b h) d s')
    softmax_scale = 1.0 / math.sqrt(head_dim)

    scores = torch.empty(batch_size * num_heads, seq_len, seq_len, dtype=qkv.dtype, device=qkv.device)
    scores = rearrange(torch.baddbmm(scores, q, k, beta=0, alpha=softmax_scale),
                       '(b h) t s -> b h t s', h=num_heads)
    if causal:
        causal_mask = torch.triu(torch.full((seq_len, seq_len), -10000.0, device=scores.device), 1)
        scores = scores + causal_mask.to(dtype=scores.dtype)
    attention = torch.softmax(scores, dim=-1)
    attention_drop = F.dropout(attention, dropout_p)
    output = torch.einsum('bhts,bshd->bthd', attention_drop , v)
    return output.to(dtype=qkv.dtype)

# ---------------------------
# Main Benchmark Function
# ---------------------------
def benchmark_attention(batch_size, seq_len, num_heads, emb_dim, impl, causal, repeats, output):

    # 初始化 wandb
    wandb.init(
        project="2025-PP-Lab6",  # 專案名稱
        config={
            "batch_size": batch_size,
            "seq_len": seq_len,
            "num_heads": num_heads,
            "emb_dim": emb_dim,
            "implementation": impl,
            "causal": causal,
            "repeats": repeats,
            "head_dim": emb_dim // num_heads
        }
    )


    assert impl in ['Pytorch', 'Flash1']
    device = 'cuda'
    dtype = torch.float16
    dropout_p = 0.0
    head_dim = emb_dim // num_heads

    qkv = torch.randn(
        batch_size, seq_len, 3, num_heads, head_dim,
        device=device, dtype=dtype, requires_grad=True
    )

    if impl == 'Flash1':
        total_len = batch_size * seq_len
        cu_seqlens = torch.arange(0, (batch_size + 1) * seq_len, step=seq_len, dtype=torch.int32, device=device)
        qkv_unpad = rearrange(qkv, 'b s three h d -> (b s) three h d')
        attention_func = lambda x, cu, tot, dp, causal: flash_attn_unpadded_qkvpacked_func(
            x, cu, tot, dropout_p=dp, causal=causal
        )
        input_tensor = qkv_unpad
        cu_input = cu_seqlens
    else:
        attention_func = lambda x, cu, tot, dp, causal: pytorch_attn_func(x, dp, causal)
        input_tensor = qkv
        cu_input = None

    torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats()

    fwd_times, bwd_times = benchmark_fwd_bwd(attention_func, input_tensor, cu_input, dropout_p, causal=causal, repeats=repeats)

    forward_time = sum(fwd_times) / len(fwd_times)
    backward_time = sum(bwd_times) / len(bwd_times)
    peak_memory_usage = torch.cuda.max_memory_allocated() / (1024**2)

    benchmark_result = {
        'forward': {
            'time(s)': forward_time,
            'FLOPS(TFLOPs/s)': efficiency(
                flops(batch_size, seq_len, head_dim, num_heads, causal, mode='fwd'),
                forward_time
            )
        },
        'backward': {
            'time(s)': backward_time,
            'FLOPS(TFLOPs/s)': efficiency(
                flops(batch_size, seq_len, head_dim, num_heads, causal, mode='bwd'),
                backward_time
            )
        },
        'forward_backward': {
            'time(s)': forward_time + backward_time,
            'FLOPS(TFLOPs/s)': efficiency(
                flops(batch_size, seq_len, head_dim, num_heads, causal, mode='fwd_bwd'),
                forward_time + backward_time
            )
        },
        'peak_memory_usage(MB)': peak_memory_usage,
    }


    wandb.log({
        "forward_time": forward_time,
        "backward_time": backward_time,
        "total_time": forward_time + backward_time,
        "forward_tflops": benchmark_result['forward']['FLOPS(TFLOPs/s)'],
        "backward_tflops": benchmark_result['backward']['FLOPS(TFLOPs/s)'],
        "total_tflops": benchmark_result['forward_backward']['FLOPS(TFLOPs/s)'],
        "peak_memory_mb": peak_memory_usage
    })

    with open(output, 'w') as json_file:
        json.dump(benchmark_result, json_file, indent=2)

    print(f"Benchmark completed. Results saved to {output}")
    print(json.dumps(benchmark_result, indent=2))

    wandb.finish()

# %%
# Run benchmark for FlashAttention v1
"""
benchmark_attention(
    batch_size=16,
    seq_len=512,
    num_heads=8,
    emb_dim=512,
    impl='Flash1',  # Choose between 'Pytorch' or 'Flash1'
    causal=True,
    repeats=30,
    output='flash1_benchmark.json'
)
"""

configs = [
    # ============================================================
    # 第一組：系統性測試 batch_size 的影響 (固定其他參數)
    # ============================================================
    {"batch_size": 1, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 2, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 4, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 8, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 32, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 64, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # ============================================================
    # 第二組：系統性測試 seq_len 的影響 (展現 O(N^2) 複雜度)
    # ============================================================
    {"batch_size": 16, "seq_len": 64, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 128, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 768, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 1536, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 2048, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # ============================================================
    # 第三組：測試不同 num_heads (並行化程度)
    # ============================================================
    # 固定 emb_dim=512
    {"batch_size": 16, "seq_len": 512, "num_heads": 1, "emb_dim": 64, "impl": "Flash1", "causal": True},   # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 2, "emb_dim": 128, "impl": "Flash1", "causal": True},  # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 4, "emb_dim": 256, "impl": "Flash1", "causal": True},  # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},  # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 1024, "impl": "Flash1", "causal": True}, # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 32, "emb_dim": 2048, "impl": "Flash1", "causal": True}, # head_dim=64

    # 固定 emb_dim=512，改變 head_dim
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},  # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 512, "impl": "Flash1", "causal": True}, # head_dim=32
    {"batch_size": 16, "seq_len": 512, "num_heads": 32, "emb_dim": 512, "impl": "Flash1", "causal": True}, # head_dim=16

    # ============================================================
    # 第四組：測試不同 emb_dim (模型大小)
    # ============================================================
    {"batch_size": 16, "seq_len": 512, "num_heads": 2, "emb_dim": 128, "impl": "Flash1", "causal": True},   # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 4, "emb_dim": 256, "impl": "Flash1", "causal": True},   # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},   # head_dim=64 (BERT-base)
    {"batch_size": 16, "seq_len": 512, "num_heads": 12, "emb_dim": 768, "impl": "Flash1", "causal": True},  # head_dim=64 (GPT-2)
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 1024, "impl": "Flash1", "causal": True}, # head_dim=64 (BERT-large)
    {"batch_size": 16, "seq_len": 512, "num_heads": 24, "emb_dim": 1536, "impl": "Flash1", "causal": True}, # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 32, "emb_dim": 2048, "impl": "Flash1", "causal": True}, # head_dim=64

    # ============================================================
    # 第五組：Pytorch vs Flash1 詳細對比
    # ============================================================
    # 小規模
    {"batch_size": 8, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},
    {"batch_size": 8, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # 中等規模
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # 大規模
    {"batch_size": 16, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},
    {"batch_size": 16, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # 超大規模
    {"batch_size": 16, "seq_len": 2048, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},
    {"batch_size": 16, "seq_len": 2048, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # 不同 emb_dim 對比
    {"batch_size": 16, "seq_len": 512, "num_heads": 12, "emb_dim": 768, "impl": "Pytorch", "causal": True},
    {"batch_size": 16, "seq_len": 512, "num_heads": 12, "emb_dim": 768, "impl": "Flash1", "causal": True},

    # ============================================================
    # 第六組：Causal vs Non-Causal 詳細對比
    # ============================================================
    # Flash1 對比
    {"batch_size": 16, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": False},
    {"batch_size": 16, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": False},
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    {"batch_size": 16, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": False},
    {"batch_size": 16, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # Pytorch 對比
    {"batch_size": 16, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": False},
    {"batch_size": 16, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},

    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": False},
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Pytorch", "causal": True},

    # ============================================================
    # 第七組：head_dim 的影響 (固定 emb_dim，改變 num_heads)
    # ============================================================
    {"batch_size": 16, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},   # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 512, "impl": "Flash1", "causal": True},  # head_dim=32
    {"batch_size": 16, "seq_len": 512, "num_heads": 32, "emb_dim": 512, "impl": "Flash1", "causal": True},  # head_dim=16

    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 1024, "impl": "Flash1", "causal": True}, # head_dim=64
    {"batch_size": 16, "seq_len": 512, "num_heads": 32, "emb_dim": 1024, "impl": "Flash1", "causal": True}, # head_dim=32
    {"batch_size": 16, "seq_len": 512, "num_heads": 64, "emb_dim": 1024, "impl": "Flash1", "causal": True}, # head_dim=16

    # ============================================================
    # 第八組：交叉測試 - batch_size x seq_len
    # ============================================================
    {"batch_size": 4, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 4, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 32, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 32, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},

    # ============================================================
    # 第九組：真實模型配置測試
    # ============================================================
    # BERT-base
    {"batch_size": 32, "seq_len": 512, "num_heads": 12, "emb_dim": 768, "impl": "Pytorch", "causal": False},
    {"batch_size": 32, "seq_len": 512, "num_heads": 12, "emb_dim": 768, "impl": "Flash1", "causal": False},

    # GPT-2 small
    {"batch_size": 16, "seq_len": 1024, "num_heads": 12, "emb_dim": 768, "impl": "Pytorch", "causal": True},
    {"batch_size": 16, "seq_len": 1024, "num_heads": 12, "emb_dim": 768, "impl": "Flash1", "causal": True},

    # BERT-large
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 1024, "impl": "Pytorch", "causal": False},
    {"batch_size": 16, "seq_len": 512, "num_heads": 16, "emb_dim": 1024, "impl": "Flash1", "causal": False},

    # GPT-2 medium
    {"batch_size": 8, "seq_len": 1024, "num_heads": 16, "emb_dim": 1024, "impl": "Pytorch", "causal": True},
    {"batch_size": 8, "seq_len": 1024, "num_heads": 16, "emb_dim": 1024, "impl": "Flash1", "causal": True},

    # ============================================================
    # 第十組：記憶體壓力測試 (逐步增加)
    # ============================================================
    {"batch_size": 64, "seq_len": 256, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 64, "seq_len": 512, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 32, "seq_len": 1024, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
    {"batch_size": 16, "seq_len": 2048, "num_heads": 8, "emb_dim": 512, "impl": "Flash1", "causal": True},
]

# 執行所有實驗
for i, config in enumerate(configs):
    head_dim = config["emb_dim"] // config["num_heads"]

    print(f"\n{'='*60}")
    print(f"Experiment {i+1}/{len(configs)}")
    print(f"{'='*60}")
    print(f"Config: batch_size={config['batch_size']}, seq_len={config['seq_len']}, "
          f"num_heads={config['num_heads']}, emb_dim={config['emb_dim']}")
    print(f"Implementation: {config['impl']}, Causal: {config['causal']}")
    print(f"head_dim = {head_dim}")
    print(f"{'='*60}\n")

    try:
        benchmark_attention(
            batch_size=config["batch_size"],
            seq_len=config["seq_len"],
            num_heads=config["num_heads"],
            emb_dim=config["emb_dim"],
            impl=config["impl"],
            causal=config["causal"],
            repeats=30,
            output=f'benchmark_exp{i+1:03d}.json'
        )
    except Exception as e:
        print(f"Experiment {i+1} failed with error: {e}")
        continue

print(f"\nAll {len(configs)} experiments completed!")
# Out:
# ============================================================
# Experiment 1/73
# ============================================================
# Config: batch_size=1, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">serene-surf-10</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/jiykm53s' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/jiykm53s</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_162821-jiykm53s/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163134-7u43d3fm</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/7u43d3fm' target="_blank">toasty-pond-2</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/7u43d3fm' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/7u43d3fm</a>
# Benchmark completed. Results saved to benchmark_exp001.json
# {
#   "forward": {
#     "time(s)": 0.00017317973325649895,
#     "FLOPS(TFLOPs/s)": 1.5500396666070415
#   },
#   "backward": {
#     "time(s)": 0.0004637173304955164,
#     "FLOPS(TFLOPs/s)": 1.4471933565279778
#   },
#   "forward_backward": {
#     "time(s)": 0.0006368970637520154,
#     "FLOPS(TFLOPs/s)": 1.4751584666840551
#   },
#   "peak_memory_usage(MB)": 72.533203125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>1.44719</td></tr><tr><td>backward_time</td><td>0.00046</td></tr><tr><td>forward_tflops</td><td>1.55004</td></tr><tr><td>forward_time</td><td>0.00017</td></tr><tr><td>peak_memory_mb</td><td>72.5332</td></tr><tr><td>total_tflops</td><td>1.47516</td></tr><tr><td>total_time</td><td>0.00064</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">toasty-pond-2</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/7u43d3fm' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/7u43d3fm</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163134-7u43d3fm/logs</code>
# ============================================================
# Experiment 2/73
# ============================================================
# Config: batch_size=2, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163137-ahyvy4sn</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ahyvy4sn' target="_blank">dainty-capybara-3</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ahyvy4sn' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ahyvy4sn</a>
# Benchmark completed. Results saved to benchmark_exp002.json
# {
#   "forward": {
#     "time(s)": 0.00023656639953454335,
#     "FLOPS(TFLOPs/s)": 2.2694301179555567
#   },
#   "backward": {
#     "time(s)": 0.0005085973342259725,
#     "FLOPS(TFLOPs/s)": 2.638978204717966
#   },
#   "forward_backward": {
#     "time(s)": 0.0007451637337605159,
#     "FLOPS(TFLOPs/s)": 2.5216581361485004
#   },
#   "peak_memory_usage(MB)": 79.126953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>2.63898</td></tr><tr><td>backward_time</td><td>0.00051</td></tr><tr><td>forward_tflops</td><td>2.26943</td></tr><tr><td>forward_time</td><td>0.00024</td></tr><tr><td>peak_memory_mb</td><td>79.12695</td></tr><tr><td>total_tflops</td><td>2.52166</td></tr><tr><td>total_time</td><td>0.00075</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dainty-capybara-3</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ahyvy4sn' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ahyvy4sn</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163137-ahyvy4sn/logs</code>
# ============================================================
# Experiment 3/73
# ============================================================
# Config: batch_size=4, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163140-82qcyfa0</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/82qcyfa0' target="_blank">sage-deluge-4</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/82qcyfa0' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/82qcyfa0</a>
# Benchmark completed. Results saved to benchmark_exp003.json
# {
#   "forward": {
#     "time(s)": 0.00037299413383007053,
#     "FLOPS(TFLOPs/s)": 2.878709680965593
#   },
#   "backward": {
#     "time(s)": 0.0007976277311642964,
#     "FLOPS(TFLOPs/s)": 3.3654228095626144
#   },
#   "forward_backward": {
#     "time(s)": 0.0011706218649943669,
#     "FLOPS(TFLOPs/s)": 3.2103418673271444
#   },
#   "peak_memory_usage(MB)": 92.501953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>3.36542</td></tr><tr><td>backward_time</td><td>0.0008</td></tr><tr><td>forward_tflops</td><td>2.87871</td></tr><tr><td>forward_time</td><td>0.00037</td></tr><tr><td>peak_memory_mb</td><td>92.50195</td></tr><tr><td>total_tflops</td><td>3.21034</td></tr><tr><td>total_time</td><td>0.00117</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sage-deluge-4</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/82qcyfa0' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/82qcyfa0</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163140-82qcyfa0/logs</code>
# ============================================================
# Experiment 4/73
# ============================================================
# Config: batch_size=8, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163144-46mhx5ii</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/46mhx5ii' target="_blank">major-bird-5</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/46mhx5ii' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/46mhx5ii</a>
# Benchmark completed. Results saved to benchmark_exp004.json
# {
#   "forward": {
#     "time(s)": 0.0006461066663265228,
#     "FLOPS(TFLOPs/s)": 3.3237292848402933
#   },
#   "backward": {
#     "time(s)": 0.0015080277442932129,
#     "FLOPS(TFLOPs/s)": 3.5600864376114134
#   },
#   "forward_backward": {
#     "time(s)": 0.0021541344106197355,
#     "FLOPS(TFLOPs/s)": 3.4891939569535135
#   },
#   "peak_memory_usage(MB)": 120.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>3.56009</td></tr><tr><td>backward_time</td><td>0.00151</td></tr><tr><td>forward_tflops</td><td>3.32373</td></tr><tr><td>forward_time</td><td>0.00065</td></tr><tr><td>peak_memory_mb</td><td>120.00195</td></tr><tr><td>total_tflops</td><td>3.48919</td></tr><tr><td>total_time</td><td>0.00215</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">major-bird-5</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/46mhx5ii' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/46mhx5ii</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163144-46mhx5ii/logs</code>
# ============================================================
# Experiment 5/73
# ============================================================
# Config: batch_size=16, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163147-y5qeotve</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/y5qeotve' target="_blank">glowing-cherry-6</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/y5qeotve' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/y5qeotve</a>
# Benchmark completed. Results saved to benchmark_exp005.json
# {
#   "forward": {
#     "time(s)": 0.0010936277310053507,
#     "FLOPS(TFLOPs/s)": 3.9272662664211344
#   },
#   "backward": {
#     "time(s)": 0.002542585611343384,
#     "FLOPS(TFLOPs/s)": 4.2230311506902805
#   },
#   "forward_backward": {
#     "time(s)": 0.0036362133423487345,
#     "FLOPS(TFLOPs/s)": 4.13407688732866
#   },
#   "peak_memory_usage(MB)": 178.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>4.22303</td></tr><tr><td>backward_time</td><td>0.00254</td></tr><tr><td>forward_tflops</td><td>3.92727</td></tr><tr><td>forward_time</td><td>0.00109</td></tr><tr><td>peak_memory_mb</td><td>178.00195</td></tr><tr><td>total_tflops</td><td>4.13408</td></tr><tr><td>total_time</td><td>0.00364</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glowing-cherry-6</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/y5qeotve' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/y5qeotve</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163147-y5qeotve/logs</code>
# ============================================================
# Experiment 6/73
# ============================================================
# Config: batch_size=32, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163150-xsdy8da8</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/xsdy8da8' target="_blank">rural-brook-7</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/xsdy8da8' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/xsdy8da8</a>
# Benchmark completed. Results saved to benchmark_exp006.json
# {
#   "forward": {
#     "time(s)": 0.0019210666735966998,
#     "FLOPS(TFLOPs/s)": 4.47144011712908
#   },
#   "backward": {
#     "time(s)": 0.0051347114721934,
#     "FLOPS(TFLOPs/s)": 4.182286891151563
#   },
#   "forward_backward": {
#     "time(s)": 0.0070557781457901,
#     "FLOPS(TFLOPs/s)": 4.261014228450259
#   },
#   "peak_memory_usage(MB)": 306.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>4.18229</td></tr><tr><td>backward_time</td><td>0.00513</td></tr><tr><td>forward_tflops</td><td>4.47144</td></tr><tr><td>forward_time</td><td>0.00192</td></tr><tr><td>peak_memory_mb</td><td>306.00195</td></tr><tr><td>total_tflops</td><td>4.26101</td></tr><tr><td>total_time</td><td>0.00706</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rural-brook-7</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/xsdy8da8' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/xsdy8da8</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163150-xsdy8da8/logs</code>
# ============================================================
# Experiment 7/73
# ============================================================
# Config: batch_size=64, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163154-9misqy09</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/9misqy09' target="_blank">swept-gorge-8</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/9misqy09' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/9misqy09</a>
# Benchmark completed. Results saved to benchmark_exp007.json
# {
#   "forward": {
#     "time(s)": 0.0025936735868453977,
#     "FLOPS(TFLOPs/s)": 6.6237591619596685
#   },
#   "backward": {
#     "time(s)": 0.009036909850438436,
#     "FLOPS(TFLOPs/s)": 4.75269463465061
#   },
#   "forward_backward": {
#     "time(s)": 0.011630583437283834,
#     "FLOPS(TFLOPs/s)": 5.169950627863123
#   },
#   "peak_memory_usage(MB)": 610.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>4.75269</td></tr><tr><td>backward_time</td><td>0.00904</td></tr><tr><td>forward_tflops</td><td>6.62376</td></tr><tr><td>forward_time</td><td>0.00259</td></tr><tr><td>peak_memory_mb</td><td>610.00195</td></tr><tr><td>total_tflops</td><td>5.16995</td></tr><tr><td>total_time</td><td>0.01163</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swept-gorge-8</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/9misqy09' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/9misqy09</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163154-9misqy09/logs</code>
# ============================================================
# Experiment 8/73
# ============================================================
# Config: batch_size=16, seq_len=64, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163158-c624ciox</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/c624ciox' target="_blank">robust-tree-9</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/c624ciox' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/c624ciox</a>
# Benchmark completed. Results saved to benchmark_exp008.json
# {
#   "forward": {
#     "time(s)": 0.00023544853379329047,
#     "FLOPS(TFLOPs/s)": 0.28502561863017384
#   },
#   "backward": {
#     "time(s)": 0.0004169493347406387,
#     "FLOPS(TFLOPs/s)": 0.4023802079079029
#   },
#   "forward_backward": {
#     "time(s)": 0.0006523978685339291,
#     "FLOPS(TFLOPs/s)": 0.3600272706712324
#   },
#   "peak_memory_usage(MB)": 80.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>0.40238</td></tr><tr><td>backward_time</td><td>0.00042</td></tr><tr><td>forward_tflops</td><td>0.28503</td></tr><tr><td>forward_time</td><td>0.00024</td></tr><tr><td>peak_memory_mb</td><td>80.00195</td></tr><tr><td>total_tflops</td><td>0.36003</td></tr><tr><td>total_time</td><td>0.00065</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-tree-9</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/c624ciox' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/c624ciox</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163158-c624ciox/logs</code>
# ============================================================
# Experiment 9/73
# ============================================================
# Config: batch_size=16, seq_len=128, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163202-wd5qp8wr</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/wd5qp8wr' target="_blank">peach-morning-10</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/wd5qp8wr' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/wd5qp8wr</a>
# Benchmark completed. Results saved to benchmark_exp009.json
# {
#   "forward": {
#     "time(s)": 0.0003237279991308848,
#     "FLOPS(TFLOPs/s)": 0.8292006150863406
#   },
#   "backward": {
#     "time(s)": 0.0006121695975462596,
#     "FLOPS(TFLOPs/s)": 1.0962462734018543
#   },
#   "forward_backward": {
#     "time(s)": 0.0009358975966771444,
#     "FLOPS(TFLOPs/s)": 1.0038748890217597
#   },
#   "peak_memory_usage(MB)": 94.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>1.09625</td></tr><tr><td>backward_time</td><td>0.00061</td></tr><tr><td>forward_tflops</td><td>0.8292</td></tr><tr><td>forward_time</td><td>0.00032</td></tr><tr><td>peak_memory_mb</td><td>94.00195</td></tr><tr><td>total_tflops</td><td>1.00387</td></tr><tr><td>total_time</td><td>0.00094</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-morning-10</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/wd5qp8wr' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/wd5qp8wr</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163202-wd5qp8wr/logs</code>
# ============================================================
# Experiment 10/73
# ============================================================
# Config: batch_size=16, seq_len=256, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163205-71qtlbkv</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/71qtlbkv' target="_blank">amber-breeze-11</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/71qtlbkv' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/71qtlbkv</a>
# Benchmark completed. Results saved to benchmark_exp010.json
# {
#   "forward": {
#     "time(s)": 0.0005120831996202469,
#     "FLOPS(TFLOPs/s)": 2.096811269723886
#   },
#   "backward": {
#     "time(s)": 0.0011205642700195314,
#     "FLOPS(TFLOPs/s)": 2.395538240705472
#   },
#   "forward_backward": {
#     "time(s)": 0.0016326474696397781,
#     "FLOPS(TFLOPs/s)": 2.3018419186532495
#   },
#   "peak_memory_usage(MB)": 122.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>2.39554</td></tr><tr><td>backward_time</td><td>0.00112</td></tr><tr><td>forward_tflops</td><td>2.09681</td></tr><tr><td>forward_time</td><td>0.00051</td></tr><tr><td>peak_memory_mb</td><td>122.00195</td></tr><tr><td>total_tflops</td><td>2.30184</td></tr><tr><td>total_time</td><td>0.00163</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">amber-breeze-11</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/71qtlbkv' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/71qtlbkv</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163205-71qtlbkv/logs</code>
# ============================================================
# Experiment 11/73
# ============================================================
# Config: batch_size=16, seq_len=512, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163209-v01l78qc</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/v01l78qc' target="_blank">legendary-paper-12</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/v01l78qc' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/v01l78qc</a>
# Benchmark completed. Results saved to benchmark_exp011.json
# {
#   "forward": {
#     "time(s)": 0.0011001472016175587,
#     "FLOPS(TFLOPs/s)": 3.903993292611263
#   },
#   "backward": {
#     "time(s)": 0.002573205327987671,
#     "FLOPS(TFLOPs/s)": 4.172779421530657
#   },
#   "forward_backward": {
#     "time(s)": 0.00367335252960523,
#     "FLOPS(TFLOPs/s)": 4.092279576993257
#   },
#   "peak_memory_usage(MB)": 178.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>4.17278</td></tr><tr><td>backward_time</td><td>0.00257</td></tr><tr><td>forward_tflops</td><td>3.90399</td></tr><tr><td>forward_time</td><td>0.0011</td></tr><tr><td>peak_memory_mb</td><td>178.00195</td></tr><tr><td>total_tflops</td><td>4.09228</td></tr><tr><td>total_time</td><td>0.00367</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">legendary-paper-12</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/v01l78qc' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/v01l78qc</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163209-v01l78qc/logs</code>
# ============================================================
# Experiment 12/73
# ============================================================
# Config: batch_size=16, seq_len=768, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163213-far6wyha</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/far6wyha' target="_blank">happy-bird-13</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/far6wyha' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/far6wyha</a>
# Benchmark completed. Results saved to benchmark_exp012.json
# {
#   "forward": {
#     "time(s)": 0.0019331776062647503,
#     "FLOPS(TFLOPs/s)": 4.998855968889468
#   },
#   "backward": {
#     "time(s)": 0.004585584020614624,
#     "FLOPS(TFLOPs/s)": 5.268509077882265
#   },
#   "forward_backward": {
#     "time(s)": 0.0065187616268793745,
#     "FLOPS(TFLOPs/s)": 5.188541841526348
#   },
#   "peak_memory_usage(MB)": 234.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>5.26851</td></tr><tr><td>backward_time</td><td>0.00459</td></tr><tr><td>forward_tflops</td><td>4.99886</td></tr><tr><td>forward_time</td><td>0.00193</td></tr><tr><td>peak_memory_mb</td><td>234.00195</td></tr><tr><td>total_tflops</td><td>5.18854</td></tr><tr><td>total_time</td><td>0.00652</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">happy-bird-13</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/far6wyha' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/far6wyha</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163213-far6wyha/logs</code>
# ============================================================
# Experiment 13/73
# ============================================================
# Config: batch_size=16, seq_len=1024, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163216-e514cc4f</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/e514cc4f' target="_blank">good-fog-14</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/e514cc4f' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/e514cc4f</a>
# Benchmark completed. Results saved to benchmark_exp013.json
# {
#   "forward": {
#     "time(s)": 0.002806781880060832,
#     "FLOPS(TFLOPs/s)": 6.120842273510636
#   },
#   "backward": {
#     "time(s)": 0.0066846975962320965,
#     "FLOPS(TFLOPs/s)": 6.425073437010681
#   },
#   "forward_backward": {
#     "time(s)": 0.00949147947629293,
#     "FLOPS(TFLOPs/s)": 6.335107429161791
#   },
#   "peak_memory_usage(MB)": 290.001953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>6.42507</td></tr><tr><td>backward_time</td><td>0.00668</td></tr><tr><td>forward_tflops</td><td>6.12084</td></tr><tr><td>forward_time</td><td>0.00281</td></tr><tr><td>peak_memory_mb</td><td>290.00195</td></tr><tr><td>total_tflops</td><td>6.33511</td></tr><tr><td>total_time</td><td>0.00949</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-fog-14</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/e514cc4f' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/e514cc4f</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163216-e514cc4f/logs</code>
# ============================================================
# Experiment 14/73
# ============================================================
# Config: batch_size=16, seq_len=1536, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163220-r0oqg0qo</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/r0oqg0qo' target="_blank">glowing-wave-15</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/r0oqg0qo' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/r0oqg0qo</a>
# Benchmark completed. Results saved to benchmark_exp014.json
# {
#   "forward": {
#     "time(s)": 0.005076259191830953,
#     "FLOPS(TFLOPs/s)": 7.614801412466423
#   },
#   "backward": {
#     "time(s)": 0.012427877362569173,
#     "FLOPS(TFLOPs/s)": 7.775806064119593
#   },
#   "forward_backward": {
#     "time(s)": 0.017504136554400127,
#     "FLOPS(TFLOPs/s)": 7.729114167016191
#   },
#   "peak_memory_usage(MB)": 402.001953125
# }
# ...
#  View run <strong style="color:#cdcd00">silver-surf-38</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/0bt9clrc' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/0bt9clrc</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163348-0bt9clrc/logs</code>
# ============================================================
# Experiment 38/73
# ============================================================
# Config: batch_size=16, seq_len=2048, num_heads=8, emb_dim=512
# Implementation: Pytorch, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163353-8fark3hx</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/8fark3hx' target="_blank">dauntless-spaceship-39</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/8fark3hx' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/8fark3hx</a>
# Benchmark completed. Results saved to benchmark_exp038.json
# {
#   "forward": {
#     "time(s)": 0.03975888188680013,
#     "FLOPS(TFLOPs/s)": 1.728405666227116
#   },
#   "backward": {
#     "time(s)": 0.05059814478556315,
#     "FLOPS(TFLOPs/s)": 3.395355552423698
#   },
#   "forward_backward": {
#     "time(s)": 0.09035702667236328,
#     "FLOPS(TFLOPs/s)": 2.6618645769312947
#   },
#   "peak_memory_usage(MB)": 4562.2509765625
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>3.39536</td></tr><tr><td>backward_time</td><td>0.0506</td></tr><tr><td>forward_tflops</td><td>1.72841</td></tr><tr><td>forward_time</td><td>0.03976</td></tr><tr><td>peak_memory_mb</td><td>4562.25098</td></tr><tr><td>total_tflops</td><td>2.66186</td></tr><tr><td>total_time</td><td>0.09036</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-spaceship-39</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/8fark3hx' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/8fark3hx</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163353-8fark3hx/logs</code>
# ============================================================
# Experiment 39/73
# ============================================================
# Config: batch_size=16, seq_len=2048, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163359-ajar1lr6</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ajar1lr6' target="_blank">swift-wave-40</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ajar1lr6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ajar1lr6</a>
# Benchmark completed. Results saved to benchmark_exp039.json
# {
#   "forward": {
#     "time(s)": 0.007697713088989258,
#     "FLOPS(TFLOPs/s)": 8.927258776934119
#   },
#   "backward": {
#     "time(s)": 0.018815755780537922,
#     "FLOPS(TFLOPs/s)": 9.130576196025036
#   },
#   "forward_backward": {
#     "time(s)": 0.02651346886952718,
#     "FLOPS(TFLOPs/s)": 9.071546607484304
#   },
#   "peak_memory_usage(MB)": 530.251953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>9.13058</td></tr><tr><td>backward_time</td><td>0.01882</td></tr><tr><td>forward_tflops</td><td>8.92726</td></tr><tr><td>forward_time</td><td>0.0077</td></tr><tr><td>peak_memory_mb</td><td>530.25195</td></tr><tr><td>total_tflops</td><td>9.07155</td></tr><tr><td>total_time</td><td>0.02651</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swift-wave-40</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ajar1lr6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ajar1lr6</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163359-ajar1lr6/logs</code>
# ============================================================
# Experiment 40/73
# ============================================================
# Config: batch_size=16, seq_len=512, num_heads=12, emb_dim=768
# Implementation: Pytorch, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163404-j6bzg74d</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/j6bzg74d' target="_blank">colorful-oath-41</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/j6bzg74d' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/j6bzg74d</a>
# Benchmark completed. Results saved to benchmark_exp040.json
# {
#   "forward": {
#     "time(s)": 0.00513384104569753,
#     "FLOPS(TFLOPs/s)": 1.2548987953959276
#   },
#   "backward": {
#     "time(s)": 0.00704390082359314,
#     "FLOPS(TFLOPs/s)": 2.286535225773403
#   },
#   "forward_backward": {
#     "time(s)": 0.01217774186929067,
#     "FLOPS(TFLOPs/s)": 1.8516222913923048
#   },
#   "peak_memory_usage(MB)": 610.2509765625
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>2.28654</td></tr><tr><td>backward_time</td><td>0.00704</td></tr><tr><td>forward_tflops</td><td>1.2549</td></tr><tr><td>forward_time</td><td>0.00513</td></tr><tr><td>peak_memory_mb</td><td>610.25098</td></tr><tr><td>total_tflops</td><td>1.85162</td></tr><tr><td>total_time</td><td>0.01218</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-oath-41</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/j6bzg74d' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/j6bzg74d</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163404-j6bzg74d/logs</code>
# ============================================================
# Experiment 41/73
# ============================================================
# Config: batch_size=16, seq_len=512, num_heads=12, emb_dim=768
# Implementation: Flash1, Causal: True
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163408-hc2cor8i</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/hc2cor8i' target="_blank">golden-bee-42</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/hc2cor8i' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/hc2cor8i</a>
# Benchmark completed. Results saved to benchmark_exp041.json
# {
#   "forward": {
#     "time(s)": 0.0013448405345280964,
#     "FLOPS(TFLOPs/s)": 4.790494321514967
#   },
#   "backward": {
#     "time(s)": 0.003684765839576721,
#     "FLOPS(TFLOPs/s)": 4.371004308336227
#   },
#   "forward_backward": {
#     "time(s)": 0.005029606374104817,
#     "FLOPS(TFLOPs/s)": 4.483169581638137
#   },
#   "peak_memory_usage(MB)": 250.251953125
# }
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>▁</td></tr><tr><td>backward_time</td><td>▁</td></tr><tr><td>forward_tflops</td><td>▁</td></tr><tr><td>forward_time</td><td>▁</td></tr><tr><td>peak_memory_mb</td><td>▁</td></tr><tr><td>total_tflops</td><td>▁</td></tr><tr><td>total_time</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>backward_tflops</td><td>4.371</td></tr><tr><td>backward_time</td><td>0.00368</td></tr><tr><td>forward_tflops</td><td>4.79049</td></tr><tr><td>forward_time</td><td>0.00134</td></tr><tr><td>peak_memory_mb</td><td>250.25195</td></tr><tr><td>total_tflops</td><td>4.48317</td></tr><tr><td>total_time</td><td>0.00503</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-bee-42</strong> at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/hc2cor8i' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/hc2cor8i</a><br> View project at: <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a><br>Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251126_163408-hc2cor8i/logs</code>
# ============================================================
# Experiment 42/73
# ============================================================
# Config: batch_size=16, seq_len=256, num_heads=8, emb_dim=512
# Implementation: Flash1, Causal: False
# head_dim = 64
# ============================================================
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251126_163411-ehqlxp1p</code>
# Syncing run <strong><a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ehqlxp1p' target="_blank">rosy-hill-43</a></strong> to <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6</a>
#  View run at <a href='https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ehqlxp1p' target="_blank">https://wandb.ai/christianz97-national-tsing-hua-university/2025-PP-Lab6/runs/ehqlxp1p</a>
